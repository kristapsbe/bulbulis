# %%
import os
import numpy as np
import rasterio
import matplotlib.image

from pathlib import Path
from scipy.ndimage import zoom, rotate

# %%
# zoom both T34 and T35 (0.2 ?)
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.zoom.html#scipy.ndimage.zoom
# then rotate T35
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.rotate.html

# %%
files = {}

for f in os.listdir("/home/kristaps/Projs/bulbulis/data_verified"):
    if ".jp2" in f:
        parts = f.split("_")
        if parts[0] not in files:
            files[parts[0]] = {}
        if parts[1] not in files[parts[0]]:
            files[parts[0]][parts[1]] = {}
        files[parts[0]][parts[1]][parts[2]] = f"/home/kristaps/Projs/bulbulis/data_verified/{f}"

# %%
dates = []
for f in files.values():
    dates += list(f.keys())
dates = sorted(list(set(dates)))

# %%
#dates = [d for d in dates if d[:4] in {'2017', '2018', '2019'}]
#dates = [d for d in dates if d[:4] in {'2017'}]
#dates = [d for d in dates if d[:6] in {'202207', '202208'}]
dates = [d for d in dates if d[:6] in {'202206', '202207', '202208', '202209', '202210'}]

# %%
gain = 2
deg = 5.1
lt_offset = 1230//2 # rotation takes an age with full sized images - going with SCL size instead
w = 10980//2
bc_offset = 4350//2
overlap = 980//2
bc_h = 4*(w-overlap)+overlap
bc_w = 3*(w-overlap)+overlap
t_h = bc_h+lt_offset
t_w = 2*bc_w-bc_offset
scale = 1.0

left_offsets = {
    #'T34VDK': (0, 0), # top left
    #'T34VEK': (0, 1),
    #'T34VFK': (0, 2),
    #'T34VDJ': (1, 0),
    'T34VEJ': (1, 1),
    'T34VFJ': (1, 2),
    #'T34VDH': (2, 0),
    'T34VEH': (2, 1),
    'T34VFH': (2, 2),
    #'T34UDG': (3, 0),
    #'T34UEG': (3, 1),
    #'T34UFG': (3, 2),
}

right_offsets = {
    #'T35VLE': (0, 0),
    'T35VME': (0, 1),
    'T35VNE': (0, 2),
    #'T35VLD': (1, 0),
    'T35VMD': (1, 1),
    'T35VND': (1, 2),
    #'T35VLC': (2, 0),
    'T35VMC': (2, 1),
    'T35VNC': (2, 2),
    #'T35ULB': (3, 0),
    #'T35UMB': (3, 1),
    #'T35UNB': (3, 2),
}

# %%
# TODO: this makes it easier to line up angles - get rid of it
right = np.dstack((np.zeros((bc_h, bc_w)), np.zeros((bc_h, bc_w)), np.zeros((bc_h, bc_w))))

composite = np.dstack((np.zeros((t_h, t_w)), np.zeros((t_h, t_w)), np.zeros((t_h, t_w))))

# %%
valid_files = set(list(left_offsets.keys())+list(right_offsets.keys()))
files = {k:v for k,v in files.items() if k in valid_files}

# %%
prev_day = ""

for d in dates:
    print(d)
    for k,v in left_offsets.items():
        if d in files[k]:
            fj = files[k][d]
            try:
                scl = rasterio.open(fj["SCL"], driver="JP2OpenJPEG").read(1)
                c_red = np.clip(rasterio.open(fj["B04"], driver="JP2OpenJPEG").read(1)*gain/10000, 0, 1)
                c_green = np.clip(rasterio.open(fj["B03"], driver="JP2OpenJPEG").read(1)*gain/10000, 0, 1) 
                c_blue = np.clip(rasterio.open(fj["B02"], driver="JP2OpenJPEG").read(1)*gain/10000, 0, 1)

                print(d, k)
                v_offset = v[0]*(w-overlap)+lt_offset
                h_offset = v[1]*(w-overlap)
                # TODO this also produces black spots - e.g. 20170619 -> 20170620
                #mask = ((scl != 0) & (scl != 1) & (scl != 3) & (scl != 7) & (scl != 8) & (scl != 9) & (scl != 10))
                mask = (((scl == 0) | (scl == 1) | (scl == 3) | (scl == 7) | (scl == 8) | (scl == 9) | (scl == 10) | ((c_red == 0) & (c_green == 0) & (c_blue == 0))) != True)
                composite[v_offset:v_offset+w, h_offset:h_offset+w, 0][mask] = c_red[mask]
                composite[v_offset:v_offset+w, h_offset:h_offset+w, 1][mask] = c_green[mask]
                composite[v_offset:v_offset+w, h_offset:h_offset+w, 2][mask] = c_blue[mask]
            except BaseException as e:
                print(e)

    #if prev_day != d[:8]: # save twice to see if there's jitter
    #    print("scaling down")
    #    scaled_down = np.clip(np.dstack((zoom(composite[:,:,0], scale), zoom(composite[:,:,1], scale), zoom(composite[:,:,2], scale))), 0, 1)
    #    print("saving composite")
    #    matplotlib.image.imsave(f"{Path.home()}/Projs/bulbulis/true_color_frames/{d[:8]}_left_only.jpeg", scaled_down)
    #else:
    #    print(f"skipping save {prev_day} = {d}")
    
    t_scl = np.zeros((bc_h, bc_w))
    did_right = False
    for k,v in right_offsets.items():
        if d in files[k]:
            fj = files[k][d]
            try:
                scl = rasterio.open(fj["SCL"], driver="JP2OpenJPEG").read(1)
                c_red = np.clip(rasterio.open(fj["B04"], driver="JP2OpenJPEG").read(1)*gain/10000, 0, 1)
                c_green = np.clip(rasterio.open(fj["B03"], driver="JP2OpenJPEG").read(1)*gain/10000, 0, 1) 
                c_blue = np.clip(rasterio.open(fj["B02"], driver="JP2OpenJPEG").read(1)*gain/10000, 0, 1)

                print(d, k)
                v_offset = v[0]*(w-overlap)
                h_offset = v[1]*(w-overlap)
                #mask = ((scl != 0) & (scl != 1) & (scl != 3) & (scl != 7) & (scl != 8) & (scl != 9) & (scl != 10) & !((right[:,:,0] == 0) & (right[:,:,1] == 0) & (right[:,:,2] == 0)))
                mask = (((scl == 0) | (scl == 1) | (scl == 3) | (scl == 7) | (scl == 8) | (scl == 9) | (scl == 10) | ((c_red == 0) & (c_green == 0) & (c_blue == 0))) != True)
                right[v_offset:v_offset+w, h_offset:h_offset+w, 0][mask] = c_red[mask]
                right[v_offset:v_offset+w, h_offset:h_offset+w, 1][mask] = c_green[mask]
                right[v_offset:v_offset+w, h_offset:h_offset+w, 2][mask] = c_blue[mask]

                t_scl[v_offset:v_offset+w, h_offset:h_offset+w] = scl
                did_right = True
            except BaseException as e:
                print(e)
    if did_right: # TODO: 20170529 -> 20170530 - something appears to go wrong with the mask
        mask = ((t_scl == 0) | (t_scl == 1) | (t_scl == 3) | (t_scl == 7) | (t_scl == 8) | (t_scl == 9) | (t_scl == 10) | ((right[:,:,0] == 0) & (right[:,:,1] == 0) & (right[:,:,2] == 0)))
        t_scl[mask] = -999 # rotation ends up interpolating values - need something exteme so that I can still tell where the clouds are
        
        temp_right = rotate(right, deg, reshape=False)
        t_scl = rotate(t_scl, deg, reshape=False)
        mask = ((t_scl > 0))
        composite[:bc_h, bc_w-bc_offset:, :][mask] = temp_right[mask] # no point in clipping here since I'll need to clip after zooming anyhow
    
    if prev_day != d[:8]:
        prev_day = d[:8]
        print("scaling down")
        #scaled_down = np.clip(np.dstack((zoom(composite[:,:,0], scale), zoom(composite[:,:,1], scale), zoom(composite[:,:,2], scale))), 0, 1)
        print("saving composite")
        matplotlib.image.imsave(f"{Path.home()}/Projs/bulbulis/full_size_true_color_frames/{d[:8]}.jpeg", np.clip(composite[9100:-10500,13700:-13500,:], 0, 1))
    else:
        print(f"skipping save {prev_day} = {d}")
# Out:
# 20220701T095041
# 20220701T095041 T34VEJ
# 20220701T095041 T34VFJ
# 20220701T095041 T34VEH
# 20220701T095041 T34VFH
# 20220701T095041 T35VME
# scaling down
# saving composite
# 20220702T092041
# 20220702T092041 T35VNE
# 20220702T092041 T35VND
# 20220702T092041 T35VMC
# 20220702T092041 T35VNC
# scaling down
# saving composite
# 20220703T094039
# 20220703T094039 T34VEJ
# 20220703T094039 T34VFJ
# 20220703T094039 T34VEH
# 20220703T094039 T34VFH
# 20220703T094039 T35VME
# 20220703T094039 T35VNE
# 20220703T094039 T35VMD
# 20220703T094039 T35VND
# 20220703T094039 T35VMC
# 20220703T094039 T35VNC
# scaling down
# saving composite
# 20220704T100041
# 20220704T100041 T34VEJ
# 20220704T100041 T34VFJ
# 20220704T100041 T34VEH
# scaling down
# saving composite
# 20220705T093051
# 20220705T093051 T34VFH
# 20220705T093051 T35VME
# 20220705T093051 T35VNE
# 20220705T093051 T35VMD
# 20220705T093051 T35VND
# 20220705T093051 T35VMC
# 20220705T093051 T35VNC
# scaling down
# saving composite
# 20220706T095039
# 20220706T095039 T34VEJ
# 20220706T095039 T34VFJ
# 20220706T095039 T34VEH
# 20220706T095039 T34VFH
# 20220706T095039 T35VME
# scaling down
# saving composite
# 20220707T092039
# 20220707T092039 T35VNE
# 20220707T092039 T35VND
# 20220707T092039 T35VMC
# 20220707T092039 T35VNC
# scaling down
# saving composite
# 20220708T094041
# 20220708T094041 T34VEJ
# 20220708T094041 T34VFJ
# 20220708T094041 T34VEH
# 20220708T094041 T34VFH
# 20220708T094041 T35VME
# 20220708T094041 T35VNE
# 20220708T094041 T35VMD
# 20220708T094041 T35VND
# 20220708T094041 T35VMC
# 20220708T094041 T35VNC
# scaling down
# saving composite
# 20220709T100029
# 20220709T100029 T34VEJ
# 20220709T100029 T34VFJ
# 20220709T100029 T34VEH
# scaling down
# saving composite
# 20220710T093039
# 20220710T093039 T34VFH
# 20220710T093039 T35VME
# 20220710T093039 T35VNE
# 20220710T093039 T35VMD
# 20220710T093039 T35VND
# 20220710T093039 T35VMC
# 20220710T093039 T35VNC
# scaling down
# saving composite
# 20220711T095041
# 20220711T095041 T34VEJ
# 20220711T095041 T34VFJ
# 20220711T095041 T34VEH
# 20220711T095041 T34VFH
# 20220711T095041 T35VME
# scaling down
# saving composite
# 20220712T092041
# 20220712T092041 T35VNE
# 20220712T092041 T35VND
# 20220712T092041 T35VMC
# 20220712T092041 T35VNC
# scaling down
# saving composite
# 20220713T093549
# 20220713T093549 T34VEJ
# 20220713T093549 T34VFJ
# 20220713T093549 T34VEH
# 20220713T093549 T34VFH
# 20220713T093549 T35VME
# 20220713T093549 T35VNE
# 20220713T093549 T35VMD
# 20220713T093549 T35VND
# 20220713T093549 T35VMC
# 20220713T093549 T35VNC
# scaling down
# saving composite
# 20220714T100041
# 20220714T100041 T34VEJ
# 20220714T100041 T34VFJ
# 20220714T100041 T34VEH
# scaling down
# saving composite
# 20220715T093051
# 20220715T093051 T34VFH
# 20220715T093051 T35VME
# 20220715T093051 T35VNE
# 20220715T093051 T35VMD
# 20220715T093051 T35VND
# 20220715T093051 T35VMC
# 20220715T093051 T35VNC
# scaling down
# saving composite
# 20220716T094549
# 20220716T094549 T34VEJ
# 20220716T094549 T34VFJ
# 20220716T094549 T34VEH
# 20220716T094549 T34VFH
# 20220716T094549 T35VME
# scaling down
# saving composite
# 20220717T091559
# 20220717T091559 T35VNE
# 20220717T091559 T35VND
# 20220717T091559 T35VMC
# 20220717T091559 T35VNC
# scaling down
# saving composite
# 20220718T094041
# 20220718T094041 T34VEJ
# 20220718T094041 T34VFJ
# 20220718T094041 T34VEH
# 20220718T094041 T34VFH
# 20220718T094041 T35VME
# 20220718T094041 T35VNE
# 20220718T094041 T35VMD
# 20220718T094041 T35VND
# 20220718T094041 T35VMC
# 20220718T094041 T35VNC
# scaling down
# saving composite
# 20220719T095559
# 20220719T095559 T34VEJ
# 20220719T095559 T34VFJ
# 20220719T095559 T34VEH
# scaling down
# saving composite
# 20220720T092559
# 20220720T092559 T34VFH
# 20220720T092559 T35VME
# 20220720T092559 T35VNE
# 20220720T092559 T35VMD
# 20220720T092559 T35VND
# 20220720T092559 T35VMC
# 20220720T092559 T35VNC
# scaling down
# saving composite
# 20220721T095041
# 20220721T095041 T34VEJ
# 20220721T095041 T34VFJ
# 20220721T095041 T34VEH
# 20220721T095041 T34VFH
# 20220721T095041 T35VME
# scaling down
# saving composite
# 20220722T092041
# 20220722T092041 T35VNE
# 20220722T092041 T35VND
# 20220722T092041 T35VMC
# 20220722T092041 T35VNC
# scaling down
# saving composite
# 20220723T093549
# 20220723T093549 T34VEJ
# 20220723T093549 T34VFJ
# 20220723T093549 T34VEH
# 20220723T093549 T34VFH
# 20220723T093549 T35VME
# 20220723T093549 T35VNE
# 20220723T093549 T35VMD
# 20220723T093549 T35VND
# 20220723T093549 T35VMC
# 20220723T093549 T35VNC
# scaling down
# saving composite
# 20220724T100041
# 20220724T100041 T34VEJ
# 20220724T100041 T34VFJ
# 20220724T100041 T34VEH
# scaling down
# saving composite
# 20220725T093041
# 20220725T093041 T34VFH
# 20220725T093041 T35VME
# 20220725T093041 T35VNE
# 20220725T093041 T35VMD
# 20220725T093041 T35VND
# 20220725T093041 T35VMC
# 20220725T093041 T35VNC
# scaling down
# saving composite
# 20220726T094549
# 20220726T094549 T34VEJ
# 20220726T094549 T34VFJ
# 20220726T094549 T34VEH
# 20220726T094549 T34VFH
# 20220726T094549 T35VME
# scaling down
# saving composite
# 20220727T091559
# 20220727T091559 T35VNE
# 20220727T091559 T35VND
# 20220727T091559 T35VMC
# 20220727T091559 T35VNC
# scaling down
# saving composite
# 20220728T094041
# 20220728T094041 T34VEJ
# 20220728T094041 T34VFJ
# 20220728T094041 T34VEH
# 20220728T094041 T34VFH
# 20220728T094041 T35VME
# 20220728T094041 T35VNE
# 20220728T094041 T35VMD
# 20220728T094041 T35VND
# 20220728T094041 T35VMC
# 20220728T094041 T35VNC
# scaling down
# saving composite
# 20220729T095559
# 20220729T095559 T34VEJ
# 20220729T095559 T34VFJ
# 20220729T095559 T34VEH
# scaling down
# saving composite
# 20220730T092559
# 20220730T092559 T34VFH
# 20220730T092559 T35VME
# 20220730T092559 T35VNE
# 20220730T092559 T35VMD
# 20220730T092559 T35VND
# 20220730T092559 T35VMC
# 20220730T092559 T35VNC
# scaling down
# saving composite
# 20220731T095041
# 20220731T095041 T34VEJ
# 20220731T095041 T34VFJ
# 20220731T095041 T34VEH
# 20220731T095041 T34VFH
# 20220731T095041 T35VME
# scaling down
# saving composite
# 20220801T092041
# 20220801T092041 T35VNE
# 20220801T092041 T35VND
# 20220801T092041 T35VMC
# 20220801T092041 T35VNC
# scaling down
# saving composite
# 20220802T093549
# 20220802T093549 T34VEJ
# 20220802T093549 T34VFJ
# 20220802T093549 T34VEH
# 20220802T093549 T34VFH
# 20220802T093549 T35VME
# 20220802T093549 T35VNE
# 20220802T093549 T35VMD
# 20220802T093549 T35VND
# 20220802T093549 T35VMC
# 20220802T093549 T35VNC
# scaling down
# saving composite
# 20220803T100041
# 20220803T100041 T34VEJ
# 20220803T100041 T34VFJ
# 20220803T100041 T34VEH
# scaling down
# saving composite
# 20220804T093051
# 20220804T093051 T34VFH
# 20220804T093051 T35VME
# 20220804T093051 T35VNE
# 20220804T093051 T35VMD
# 20220804T093051 T35VND
# 20220804T093051 T35VMC
# 20220804T093051 T35VNC
# scaling down
# saving composite
# 20220805T094549
# 20220805T094549 T34VEJ
# 20220805T094549 T34VFJ
# 20220805T094549 T34VEH
# 20220805T094549 T34VFH
# 20220805T094549 T35VME
# scaling down
# saving composite
# 20220806T091559
# 20220806T091559 T35VNE
# 20220806T091559 T35VND
# 20220806T091559 T35VMC
# 20220806T091559 T35VNC
# scaling down
# saving composite
# 20220807T093601
# 20220807T093601 T34VEJ
# 20220807T093601 T34VFJ
# 20220807T093601 T34VEH
# 20220807T093601 T34VFH
# 20220807T093601 T35VME
# 20220807T093601 T35VNE
# 20220807T093601 T35VMD
# 20220807T093601 T35VND
# 20220807T093601 T35VMC
# 20220807T093601 T35VNC
# scaling down
# saving composite
# 20220808T095559
# 20220808T095559 T34VEJ
# 20220808T095559 T34VFJ
# 20220808T095559 T34VEH
# scaling down
# saving composite
# 20220809T092559
# 20220809T092559 T34VFH
# 20220809T092559 T35VME
# 20220809T092559 T35VNE
# 20220809T092559 T35VMD
# 20220809T092559 T35VND
# 20220809T092559 T35VMC
# 20220809T092559 T35VNC
# scaling down
# saving composite
# 20220810T094601
# 20220810T094601 T34VEJ
# 20220810T094601 T34VFJ
# 20220810T094601 T34VEH
# 20220810T094601 T34VFH
# 20220810T094601 T35VME
# scaling down
# saving composite
# 20220811T091611
# 20220811T091611 T35VNE
# 20220811T091611 T35VND
# 20220811T091611 T35VMC
# 20220811T091611 T35VNC
# scaling down
# saving composite
# 20220812T093549
# 20220812T093549 T34VEJ
# 20220812T093549 T34VFJ
# 20220812T093549 T34VEH
# 20220812T093549 T34VFH
# 20220812T093549 T35VME
# 20220812T093549 T35VNE
# 20220812T093549 T35VMD
# 20220812T093549 T35VND
# 20220812T093549 T35VMC
# 20220812T093549 T35VNC
# scaling down
# saving composite
# 20220813T095601
# 20220813T095601 T34VEJ
# 20220813T095601 T34VFJ
# 20220813T095601 T34VEH
# scaling down
# saving composite
# 20220814T092601
# 20220814T092601 T34VFH
# 20220814T092601 T35VME
# 20220814T092601 T35VNE
# 20220814T092601 T35VMD
# 20220814T092601 T35VND
# 20220814T092601 T35VMC
# 20220814T092601 T35VNC
# scaling down
# saving composite
# 20220815T094549
# 20220815T094549 T34VEJ
# 20220815T094549 T34VFJ
# 20220815T094549 T34VEH
# 20220815T094549 T34VFH
# 20220815T094549 T35VME
# scaling down
# saving composite
# 20220816T091559
# 20220816T091559 T35VNE
# 20220816T091559 T35VND
# 20220816T091559 T35VMC
# 20220816T091559 T35VNC
# scaling down
# saving composite
# 20220817T093601
# 20220817T093601 T34VEJ
# 20220817T093601 T34VFJ
# 20220817T093601 T34VEH
# 20220817T093601 T34VFH
# 20220817T093601 T35VME
# 20220817T093601 T35VNE
# 20220817T093601 T35VMD
# 20220817T093601 T35VND
# 20220817T093601 T35VMC
# 20220817T093601 T35VNC
# scaling down
# saving composite
# 20220818T095549
# 20220818T095549 T34VEJ
# 20220818T095549 T34VFJ
# 20220818T095549 T34VEH
# scaling down
# saving composite
# 20220819T092549
# 20220819T092549 T34VFH
# 20220819T092549 T35VME
# 20220819T092549 T35VNE
# 20220819T092549 T35VMD
# 20220819T092549 T35VND
# 20220819T092549 T35VMC
# 20220819T092549 T35VNC
# scaling down
# saving composite
# 20220820T094601
# 20220820T094601 T34VEJ
# 20220820T094601 T34VFJ
# 20220820T094601 T34VEH
# 20220820T094601 T34VFH
# 20220820T094601 T35VME
# scaling down
# saving composite
# 20220821T091611
# 20220821T091611 T35VNE
# 20220821T091611 T35VND
# 20220821T091611 T35VMC
# 20220821T091611 T35VNC
# scaling down
# saving composite
# 20220822T093549
# 20220822T093549 T34VEJ
# 20220822T093549 T34VFJ
# 20220822T093549 T34VEH
# 20220822T093549 T34VFH
# 20220822T093549 T35VME
# 20220822T093549 T35VNE
# 20220822T093549 T35VMD
# 20220822T093549 T35VND
# 20220822T093549 T35VMC
# 20220822T093549 T35VNC
# scaling down
# saving composite
# 20220823T095601
# 20220823T095601 T34VEJ
# 20220823T095601 T34VFJ
# 20220823T095601 T34VEH
# scaling down
# saving composite
# 20220824T093051
# 20220824T093051 T34VFH
# 20220824T093051 T35VME
# 20220824T093051 T35VNE
# 20220824T093051 T35VMD
# 20220824T093051 T35VND
# 20220824T093051 T35VMC
# 20220824T093051 T35VNC
